# %% [markdown]
# # Páginas para programar python

# %% [markdown]
# 1. www.mybinder.org
# 2. www.kaggle.com
# 3. www.jupyter.org/try
# 4. `github jobish` https://mybinder.org/v2/gh/jobish03/jobish03-Visualizacion_de_datos_para_la_toma_de_decisiones/main?filepath=welcome_binder.ipynb
#
# Los paquetes hay que incluir en el archivo `requirements.txt`

# %% [markdown]
# # Clase 1 - Introducción

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# # Cargando Librerias

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.66196528, 0.6823277 , 0.0430677 , 0.69805679, 0.64632476,
#        0.21624607, 0.43612688, 0.09349123, 0.00575253, 0.40611419,
#        0.00984176, 0.69729867, 0.60351688, 0.80682776, 0.2753928 ,
#        0.33527465, 0.46981824, 0.95726251, 0.84288361, 0.07410892,
#        0.43750074, 0.02425251, 0.35301969, 0.56787879, 0.66135684,
#        0.96952217, 0.05310617, 0.71589169, 0.78584867, 0.7748393 ,
#        0.00619866, 0.33371599, 0.33803159, 0.29001894, 0.51121748,
#        0.8107    , 0.87216292, 0.66025205, 0.85231409, 0.3440196 ,
#        0.82161241, 0.91750339, 0.6831288 , 0.69718943, 0.6918361 ,
#        0.43798323, 0.6110977 , 0.66046795, 0.61283936, 0.05270352])

# %%
# %ls datasets/
# Out:
# ls: cannot access 'datasets/': No such file or directory

# %% [markdown]
# # Tipos de Datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[4]
# Out:
# 5

# %%
type(numbers)
# Out:
# list

# %%
sum_ = sum(numbers)
sum_
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type('math.pi')
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type('False')
# Out:
# str

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
    print(x,'es mayor que', y)
# Out:
# 16 es mayor que 8

# %%
unalista = [True, 6<5, 1==3, None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# # el uso de for loop

# %%
for element in unalista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # lista

# %%
unaLista = ['first','second','third','forth','fifth', 'sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
#unalista.sort()
#unalista
# Out:
# ['fifth', 'first', 'forth', 'second', 'sixth', 'third']

# %%
unaLista[:1]
# Out:
# ['first']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
unaLista[1:3] #sin incluir el elemento en la posición 3
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1] #de atras para adelante
# Out:
# 'sixth'

# %%
unaLista[-3:-1] #no incluye el ultimo en posicion -1
# Out:
# ['forth', 'fifth', 'sixth']

# %%
unaLista[-3:]
# Out:
# ['forth', 'fifth', 'sixth']
