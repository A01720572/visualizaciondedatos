# %% [markdown]
# # pivot tables

# %%
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    census.csv
# 00_00_primer_pasos.ipynb              coches.csv
# 01_01_data_types.ipynb                cwurData.csv
# 01_02_read_iloc_unique_groupby.ipynb  data.csv
# 02_00_data_wrangling.ipynb            headbrain.csv
# 02_01_null_display.ipynb              mic2.xlsx
# 02_02_basic_math.ipynb                mic.xlsx
# A3.ipynb                              movies.csv
# adult.csv                             nhanes_2015_2016.csv
# airline_data.csv                      pokemon.csv
# antropometria00.csv                   README.md
# antropometria-dataset-2.csv           requirements.txt
# antropometria-dataset.csv             S3.ipynb
# Book3.csv                             sample_pivot.csv
# Canada.xlsx                           tips.csv
# Cartwheeldata.csv                     weight-height.csv

# %%
df = pd.read_csv('antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df,
                          index = ['desc_ent'],
                          values = ['peso'],
                          aggfunc = 'median',
                          columns = ['sexo']
                         )
my_pivot
# Out:
#                                     peso
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# ...

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    census.csv
# 00_00_primer_pasos.ipynb              coches.csv
# 01_01_data_types.ipynb                cwurData.csv
# 01_02_read_iloc_unique_groupby.ipynb  data.csv
# 02_00_data_wrangling.ipynb            headbrain.csv
# 02_01_null_display.ipynb              mic2.xlsx
# 02_02_basic_math.ipynb                mic.xlsx
# A3.ipynb                              movies.csv
# adult.csv                             nhanes_2015_2016.csv
# airline_data.csv                      pokemon.csv
# antropometria00.csv                   README.md
# antropometria-dataset-2.csv           requirements.txt
# antropometria-dataset.csv             S3.ipynb
# Book3.csv                             sample_pivot.csv
# Canada.xlsx                           tips.csv
# Cartwheeldata.csv                     weight-height.csv

# %%
df = pd.read_csv('adult.csv')
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df,
                          index = ['sex','marital-status'],
                          values = ['age'],
                          aggfunc = 'median',
                          columns = ['education']
                         )
my_pivot
# Out:
#                                  age                                         \
# education                       10th  11th  12th  1st-4th  5th-6th  7th-8th
# sex     marital-status
#  Female  Divorced               45.0  41.0  41.0     64.0     53.0     52.0
#          Married-AF-spouse       NaN   NaN   NaN      NaN      NaN      NaN
#          Married-civ-spouse     32.0  42.0  34.0     44.5     43.0     46.0
#          Married-spouse-absent  39.0  30.0  25.5     33.0     50.0     44.0
#          Never-married          18.0  18.0  18.0     32.0     32.0     31.0
#          Separated              34.0  35.5  35.0     50.0     39.0     45.0
#          Widowed                60.0  56.0  56.0     63.0     65.0     64.0
#          test_category_female    NaN   NaN   NaN      NaN      NaN      NaN
#  Male    Divorced               39.0  38.0  41.0     63.0     56.0     49.5
#          Married-AF-spouse       NaN   NaN   NaN      NaN      NaN      NaN
# ...
